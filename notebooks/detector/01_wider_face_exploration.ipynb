# %%
# %cd /content
# !rm -rf face-biometrics
# !git clone https://github.com/Krish9N/face-biometrics.git
# %cd face-biometrics
# Out:
# /content
# Cloning into 'face-biometrics'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 34 (delta 7), reused 25 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 6.71 KiB | 3.36 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/face-biometrics

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/face-biometrics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for face-biometrics (pyproject.toml) ... done
#   Created wheel for face-biometrics: filename=face_biometrics-0.1.0-0.editable-py3-none-any.whl size=1351 sha256=7db52d6a30e8618399e0c4522b87570f4d2ac7472d20b20e797d710878bcb4fe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7bc_bpfe/wheels/81/14/56/5332cf3623ff931271bf46e2537bc7029820cbc08943974ad0
# Successfully built face-biometrics
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from face_biometrics.datasets.wider_face import WiderFaceDataset

# %%
from pathlib import Path

WIDER_ROOT = Path(
    "/content/drive/MyDrive/face-biometrics/datasets/WIDER_FACE"
)

image_root = WIDER_ROOT / "WIDER_train" / "images"

annotation_file = (
    WIDER_ROOT
    / "wider_face_split"
    / "wider_face_train_bbx_gt.txt"
)

dataset = WiderFaceDataset(
    image_root=image_root,
    annotation_file=annotation_file,
)

print("Number of samples:", len(dataset))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9204/1118065518.py in <cell line: 0>()
#      13 )
#      14
# ---> 15 dataset = WiderFaceDataset(
#      16     image_root=image_root,
#      17     annotation_file=annotation_file,
#
# /content/face-biometrics/src/face_biometrics/datasets/wider_face.py in __init__(self, image_root, annotation_file)
#      15         self.annotation_file = Path(annotation_file)
#      16
# ---> 17         self.samples = self._load_annotations()
#      18
#      19     def _load_annotations(self) -> list[FaceSample]:
#
# /content/face-biometrics/src/face_biometrics/datasets/wider_face.py in _load_annotations(self)
#      32
#      33             # Number of annotated faces
# ---> 34             num_faces = int(lines[i])
#      35             i += 1
#      36
#
# ...
